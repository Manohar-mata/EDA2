# %% [markdown]
# ## Analyzing Penguins Data

# %% [markdown]
# ## Introduction
# >Welcome to my project of analyzing the penguins data using Pandas. In this project, we'll walk through various data analysis tasks, from loading the dataset to drawing the insights through visualization.
#
# ## Objectives:
# 1.Load and understand the dataset.
#
# 2.Perform basic data cleaning and preparation.
#
# 3.Perform univariate analysis.
#
# 4.Perfrom Bivariate analysis.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Load and understand the data

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/FoundationAA(ASS)/Penguins/penguins_lter.csv")
df.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion  Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  11/16/07
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  11/16/07
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  11/16/07
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# ...

# %%
df.columns
# Out:
# Index(['studyName', 'Sample Number', 'Species', 'Region', 'Island', 'Stage',
#        'Individual ID', 'Clutch Completion', 'Date Egg', 'Culmen Length (mm)',
#        'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Sex',
#        'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)', 'Comments'],
#       dtype='object')

# %%
## The columns delt.. delta 13.. both have the floating value which exceeds more than .2 decimals
pd.set_option('display.float_format','{:.2f}'.format)
df.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion  Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  11/16/07
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  11/16/07
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  11/16/07
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# ...

# %%
## Lets find out the null value in the data
col_name=df.isna().sum()
col_name
# Out:
# studyName                0
# Sample Number            0
# Species                  0
# Region                   0
# Island                   0
# Stage                    0
# Individual ID            0
# Clutch Completion        0
# Date Egg                 0
# Culmen Length (mm)       2
# Culmen Depth (mm)        2
# Flipper Length (mm)      2
# Body Mass (g)            2
# Sex                     10
# Delta 15 N (o/oo)       14
# Delta 13 C (o/oo)       13
# Comments               318
# dtype: int64

# %%
df.shape
# Out:
# (344, 17)

# %%
# Out of 344 records 318 null values present in the Comments column so lets delete that.
df.drop('Comments',axis=1,inplace = True)
df.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion  Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  11/16/07
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  11/16/07
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  11/16/07
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# ...

# %%
df.dtypes
# Out:
# studyName               object
# Sample Number            int64
# Species                 object
# Region                  object
# Island                  object
# Stage                   object
# Individual ID           object
# Clutch Completion       object
# Date Egg                object
# Culmen Length (mm)     float64
# Culmen Depth (mm)      float64
# Flipper Length (mm)    float64
# Body Mass (g)          float64
# Sex                     object
# Delta 15 N (o/oo)      float64
# Delta 13 C (o/oo)      float64
# dtype: object

# %%
# Date Egg column is object we need to convert to Date dtype
df['Date Egg']=pd.to_datetime(df['Date Egg'],errors='coerce')
print(df['Date Egg'].dtype)
# Out:
# datetime64[ns]
# <ipython-input-10-eae8f76c9785>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date Egg']=pd.to_datetime(df['Date Egg'],errors='coerce')

# %%
df.describe()
# Out:
#        Sample Number                       Date Egg  Culmen Length (mm)  \
# count         344.00                            344              342.00
# mean           63.15  2008-11-27 03:46:02.790697728               43.92
# min             1.00            2007-11-09 00:00:00               32.10
# 25%            29.00            2007-11-28 00:00:00               39.23
# 50%            58.00            2008-11-09 00:00:00               44.45
# 75%            95.25            2009-11-16 00:00:00               48.50
# max           152.00            2009-12-01 00:00:00               59.60
# std            40.43                            NaN                5.46
#
#        Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# count             342.00               342.00         342.00
# mean               17.15               200.92        4201.75
# min                13.10               172.00        2700.00
# 25%                15.60               190.00        3550.00
# ...

# %% [markdown]
# ## Here the data contain the nan values in the both numeric and categorical columns

# %%
#Numeric
df.fillna(df.select_dtypes(include='number').mean(),inplace=True)
#Non-Numeric
#df['Sex'].fillna('Unknown',inplace=True)
df['Sex'].replace('.','Unknown')

df.isna().sum()
# Out:
# studyName               0
# Sample Number           0
# Species                 0
# Region                  0
# Island                  0
# Stage                   0
# Individual ID           0
# Clutch Completion       0
# Date Egg                0
# Culmen Length (mm)      0
# Culmen Depth (mm)       0
# Flipper Length (mm)     0
# Body Mass (g)           0
# Sex                    10
# Delta 15 N (o/oo)       0
# Delta 13 C (o/oo)       0
# dtype: int64

# %%
#duplicate records
pd.options.display.max_rows = None

df.duplicated()==True
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
df.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion   Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes 2007-11-11
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes 2007-11-11
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes 2007-11-16
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes 2007-11-16
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes 2007-11-16
#
# ...

# %% [markdown]
# ## univariate analysis
# >Numerical ->Histogram
#
# >Non-numerical ->Barplot

# %%
# Lets find out the Numeric colummns and non-numerical columns
num_col=df.select_dtypes(include=['int64','float64']).columns
non_num_col=df.select_dtypes(include=['object']).columns

#lets create a data frame for this
classifying_col=pd.DataFrame({'numeric_null':pd.Series(num_col),
                              'non-num_null':pd.Series(non_num_col)})
#Include the columns that contain only null values
classifying_col
# Out:
#           numeric_null       non-num_null
# 0        Sample Number          studyName
# 1   Culmen Length (mm)            Species
# 2    Culmen Depth (mm)             Region
# 3  Flipper Length (mm)             Island
# 4        Body Mass (g)              Stage
# 5    Delta 15 N (o/oo)      Individual ID
# 6    Delta 13 C (o/oo)  Clutch Completion
# 7                  NaN                Sex

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#plot histogram and boxplot for each numeric column
for column in num_col:
  plt.figure(figsize=(10,5))

  #Histogram
  plt.subplot(1,2,1)
  sns.histplot(df[column],kde=True, color='green')
  plt.title(f'Histogram of {column}')
  plt.xlabel(column)
  plt.tight_layout()
  plt.show()

  #boxplot
  plt.subplot(1,2,2)
  sns.boxplot(df[column],color='salmon')
  plt.title(f'Box plot of {column}')
  plt.xlabel(column)

  plt.tight_layout()
  plt.show()

  #summary satistics
  print(f"\nsummary statistics for {column}")
  print(df[column].describe())
  print('\n'+"="*50 +'\n')
# Out:
# summary statistics for Sample Number
# count   344.00
# mean     63.15
# std      40.43
# min       1.00
# 25%      29.00
# 50%      58.00
# 75%      95.25
# max     152.00
# Name: Sample Number, dtype: float64
#
# ...
# summary statistics for Culmen Length (mm)
# count   344.00
# mean     43.92
# std       5.44
# min      32.10
# 25%      39.27
# 50%      44.25
# 75%      48.50
# max      59.60
# Name: Culmen Length (mm), dtype: float64
#
# ...
# summary statistics for Culmen Depth (mm)
# count   344.00
# mean     17.15
# std       1.97
# min      13.10
# 25%      15.60
# 50%      17.30
# 75%      18.70
# max      21.50
# Name: Culmen Depth (mm), dtype: float64
#
# ...
# summary statistics for Flipper Length (mm)
# count   344.00
# mean    200.92
# std      14.02
# min     172.00
# 25%     190.00
# 50%     197.00
# 75%     213.00
# max     231.00
# Name: Flipper Length (mm), dtype: float64
#
# ...
# summary statistics for Body Mass (g)
# count    344.00
# mean    4201.75
# std      799.61
# ...

# %%
# Plot bar plots for each categorical column
for column in non_num_col:
  # exclude individual id column
    if column == 'Individual ID':
       continue

    plt.figure(figsize=(10, 5))
    sns.countplot(data=df, x=column, hue=column, dodge=False, order=df[column].value_counts().index, legend=False)
    plt.xticks(rotation=45)
    plt.title(f'Count Plot of {column}')
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.show()

    # Value counts
    print(f"\nValue counts for {column}:")
    print(df[column].value_counts())
    print("\n" + "="*50 + "\n")
# Out:
# Value counts for studyName:
# studyName
# PAL0910    120
# PAL0809    114
# PAL0708    110
# Name: count, dtype: int64
#
# ...
# Value counts for Species:
# Species
# Adelie Penguin (Pygoscelis adeliae)          152
# Gentoo penguin (Pygoscelis papua)            124
# Chinstrap penguin (Pygoscelis antarctica)     68
# Name: count, dtype: int64
#
# ...
# Value counts for Region:
# Region
# Anvers    344
# Name: count, dtype: int64
#
# ...
# Value counts for Island:
# Island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64
#
# ...
# Value counts for Stage:
# Stage
# Adult, 1 Egg Stage    344
# Name: count, dtype: int64
#
# ...
# Value counts for Clutch Completion:
# Clutch Completion
# Yes    308
# No      36
# Name: count, dtype: int64
#
# ...
# Value counts for Sex:
# Sex
# MALE      168
# FEMALE    165
# .           1
# Name: count, dtype: int64
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

# Select numerical columns
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns

# Define number of columns for grid layout
n_cols = 2
n_rows = math.ceil(len(numerical_columns) * 2 / n_cols)

# Set up the matplotlib figure for histograms and box plots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(14, n_rows * 2.5))
fig.tight_layout(pad=3.0)
axes = axes.flatten()  # Flatten axes array for easy indexing

# Plot each numerical column in a grid
for i, column in enumerate(numerical_columns):
    # Histogram with KDE
    sns.histplot(df[column], kde=True, ax=axes[2 * i], color='skyblue')
    axes[2 * i].set_title(f'Histogram of {column}')
    axes[2 * i].set_xlabel(column)
    axes[2 * i].set_ylabel('Frequency')

    # Box Plot
    sns.boxplot(x=df[column], ax=axes[2 * i + 1], color='salmon')
    axes[2 * i + 1].set_title(f'Box Plot of {column}')
    axes[2 * i + 1].set_xlabel(column)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

# Select categorical columns
categorical_columns = df.select_dtypes(include=['object']).columns

# Define number of columns for grid layout
n_cols = 3
n_rows = math.ceil(len(categorical_columns) / n_cols)

# Set up the matplotlib figure for bar plots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, n_rows * 3))
fig.tight_layout(pad=3.0)
plt.subplots_adjust(hspace=0.6)  # Increase space between rows
axes = axes.flatten()  # Flatten axes array for easy indexing

# Plot each categorical column in a grid
for i, column in enumerate(categorical_columns):
    if column == 'Individual ID':
      continue
    # Bar Plot for each categorical variable
    sns.countplot(data=df, x=column, order=df[column].value_counts().index, ax=axes[i], color='skyblue')
    axes[i].set_title(f'Count Plot of {column}')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Count')
    axes[i].tick_params(axis='x', rotation=30)

# Hide any unused subplots in the grid
for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

# Show the plot
plt.show()

# %%
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns
correlation_matrix = df[numerical_columns].corr()
correlation_matrix
# Out:
#                      Sample Number  Culmen Length (mm)  Culmen Depth (mm)  \
# Sample Number                 1.00               -0.23              -0.02
# Culmen Length (mm)           -0.23                1.00              -0.24
# Culmen Depth (mm)            -0.02               -0.24               1.00
# Flipper Length (mm)           0.04                0.66              -0.58
# Body Mass (g)                -0.01                0.60              -0.47
# Delta 15 N (o/oo)             0.01               -0.06               0.60
# Delta 13 C (o/oo)            -0.48                0.19               0.42
#
#                      Flipper Length (mm)  Body Mass (g)  Delta 15 N (o/oo)  \
# Sample Number                       0.04          -0.01               0.01
# Culmen Length (mm)                  0.66           0.60              -0.06
# Culmen Depth (mm)                  -0.58          -0.47               0.60
# ...

# %%
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',vmin=-1,vmax=1)
plt.xticks(rotation=45)
plt.title("Correlatin Matrix")
plt.show()

# %%
df.columns
# Out:
# Index(['studyName', 'Sample Number', 'Species', 'Region', 'Island', 'Stage',
#        'Individual ID', 'Clutch Completion', 'Date Egg', 'Culmen Length (mm)',
#        'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Sex',
#        'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)'],
#       dtype='object')

# %%
selected_columns = ['Species', 'Island', 'Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Sex']
df_final=df[selected_columns]
df_final.head()
# Out:
#                                Species     Island  Culmen Length (mm)  \
# 0  Adelie Penguin (Pygoscelis adeliae)  Torgersen               39.10
# 1  Adelie Penguin (Pygoscelis adeliae)  Torgersen               39.50
# 2  Adelie Penguin (Pygoscelis adeliae)  Torgersen               40.30
# 3  Adelie Penguin (Pygoscelis adeliae)  Torgersen               43.92
# 4  Adelie Penguin (Pygoscelis adeliae)  Torgersen               36.70
#
#    Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)     Sex
# 0              18.70               181.00        3750.00    MALE
# 1              17.40               186.00        3800.00  FEMALE
# 2              18.00               195.00        3250.00  FEMALE
# 3              17.15               200.92        4201.75     NaN
# 4              19.30               193.00        3450.00  FEMALE

# %%
df_final['Species'] = df_final['Species'].str.split(" ").str.get(0)
# Out:
# <ipython-input-27-6705178791c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Species'] = df_final['Species'].str.split(" ").str.get(0)

# %%
df_final['Species'].value_counts()
# Out:
# Species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
sns.histplot(data=df_final, x='Body Mass (g)',hue='Species')
plt.ylabel('Frequency')
plt.xlabel('Body Mass (g)')
plt.title('Distribution of Body Mass by species')
# Out:
# Text(0.5, 1.0, 'Distribution of Body Mass by species')

# %%
sns.boxplot(data=df_final,x='Species',y='Body Mass (g)',hue='Species')
# Out:
# <Axes: xlabel='Species', ylabel='Body Mass (g)'>

# %%
sns.countplot(data=df_final,x='Island',hue='Species')
# Out:
# <Axes: xlabel='Island', ylabel='count'>

# %%
sns.scatterplot(data=df_final, x='Body Mass (g)', y='Culmen Depth (mm)', hue='Species')
# Out:
# <Axes: xlabel='Body Mass (g)', ylabel='Culmen Depth (mm)'>

# %%
df_final.to_csv('penguins_final.csv', index=False)
